# %%
import os
os.environ['DATA_PATH'] = '../../FeatureExtractionOutLCCMini3/'

import pandas as pd
pd.set_option('display.max_rows', 100)

import scipy
import seaborn as sns
import sys
sys.path.append('../nemo-eva/src/')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df_clean = pd.read_csv(os.environ['DATA_PATH'] + '3-cleaned_features/results.csv')
df_clean.Info = df_clean.Info.apply(lambda temp: {'Info': temp} if '|' not in temp else {key: var for key, var in [x.split('=') for x in temp.split('|')]})
df_real = df_clean.loc[df_clean.Model == 'real-world']
df_clean['alpha'] = df_clean.Info.apply(lambda x: x['alpha'] if 'alpha' in x else 1/float(x['t']) if 't' in x else None)
df_clean.shape

df_raw = pd.read_csv(os.environ['DATA_PATH'] + '2-features/results.csv')
import feature_cleaner
graph_dicts = df_raw.to_dict('records')
fc = feature_cleaner.FeatureCleaner(graph_dicts)
fc.resultspath = './temp/results.csv'
fc._stagepath = './temp/'
fc.resultspath
# Out:
# (1881, 238)
# './temp/results.csv'

# %%
fc.execute()
# Out:
# Feature: 296 ( unfiltered: 346 )
# missing graphs for 1d-cube-girg model: {'bn-human-BNU_1_0025873_session_1-bg', 'bn-human-BNU_1_0025889_session_2', 'ca-GrQc', 'socfb-UC61'}
# missing graphs for ER model: {'bn-human-BNU_1_0025873_session_1-bg', 'bn-human-BNU_1_0025889_session_2'}
# missing graphs for 2d-cube-girg model: {'bn-human-BNU_1_0025873_session_1-bg', 'bn-human-BNU_1_0025889_session_2', 'socfb-Baylor93', 'soc-themarker', 'ca-GrQc', 'socfb-Syracuse56', 'socfb-UC61', 'socfb-Temple83'}
# missing graphs for chung-lu model: {'bn-human-BNU_1_0025873_session_1-bg', 'bn-human-BNU_1_0025889_session_2'}
# missing graphs for 3d-cube-girg model: {'bn-human-BNU_1_0025873_session_1-bg', 'bn-human-BNU_1_0025889_session_2', 'socfb-Baylor93', 'socfb-GWU54', 'ca-GrQc', 'soc-loc-brightkite', 'socfb-Stanford3', 'soc-themarker', 'ia-wiki-Talk', 'soc-brightkite', 'socfb-NotreDame57', 'socfb-Syracuse56', 'soc-anybeat', 'socfb-USF51', 'ia-enron-email-dynamic', 'ia-wikiquote-user-edits', 'socfb-UC61', 'socfb-Temple83'}
# missing graphs for BA circle model: {'bn-human-BNU_1_0025873_session_1-bg', 'bn-human-BNU_1_0025889_session_2'}
# missing graphs for hyperbolic model: {'bn-human-BNU_1_0025873_session_1-bg', 'bn-human-BNU_1_0025889_session_2'}
# missing graphs for BA full model: {'bn-human-BNU_1_0025873_session_1-bg', 'bn-human-BNU_1_0025889_session_2'}
# Graph: 927 ( unfiltered: 1097 )
#
# Filter graphs with rules:
# total            103
# --------------------
# CC = 0             0 []
# edges < 50         0 []
# nodes < 100        0 []
# --------------------
# to filter          0 []
# --------------------
# total filtered   103
#
# filter originally weighted graphs []
# filtering cols (notfinite):
#     Centrality.Betweenness.Location.Harmonic Mean
#     Centrality.ClusteringCoefficient.Dispersion.Coefficient Of Variation
#     Centrality.ClusteringCoefficient.Dispersion.Uncorrected Coefficient Of Variation
#     Centrality.ClusteringCoefficient.Location.Harmonic Mean
#     Centrality.ClusteringCoefficient.Shape.Kurtosis
#     Centrality.ClusteringCoefficient.Shape.Skewness M
#     Centrality.ClusteringCoefficient.Shape.Skewness YP
#     Centrality.CoreDecomposition.Shape.Kurtosis
#     Centrality.CoreDecomposition.Shape.Skewness M
#     Centrality.CoreDecomposition.Shape.Skewness YP
#     Partition.ConnectedComponents.Dispersion.Coefficient Of Variation
#     Partition.ConnectedComponents.Dispersion.Coefficient Of Variation (Rank)
#     Partition.ConnectedComponents.Dispersion.Standard Deviation
#     Partition.ConnectedComponents.Dispersion.Standard Deviation (Rank)
#     Partition.ConnectedComponents.Dispersion.Variance
#     Partition.ConnectedComponents.Dispersion.Variance (Rank)
#     Partition.ConnectedComponents.Shape.Kurtosis
#     Partition.ConnectedComponents.Shape.Skewness M
#     Partition.ConnectedComponents.Shape.Skewness YP
#     Partition.CoreDecomposition.Dispersion.Coefficient Of Variation
#     Partition.CoreDecomposition.Dispersion.Coefficient Of Variation (Rank)
#     Partition.CoreDecomposition.Dispersion.Standard Deviation
#     Partition.CoreDecomposition.Dispersion.Standard Deviation (Rank)
#     Partition.CoreDecomposition.Dispersion.Variance
#     Partition.CoreDecomposition.Dispersion.Variance (Rank)
#     Partition.CoreDecomposition.Shape.Kurtosis
#     Partition.CoreDecomposition.Shape.Skewness M
#     Partition.CoreDecomposition.Shape.Skewness YP
# filtering cols (low variation):
#     Centrality.Betweenness.Dispersion.Coefficient Of Variation (Rank)
#     Centrality.Betweenness.Dispersion.Uncorrected Coefficient Of Variation (Rank)
#     Centrality.Closeness.Dispersion.Coefficient Of Variation (Rank)
#     Centrality.Closeness.Dispersion.Uncorrected Coefficient Of Variation (Rank)
#     Centrality.Closeness.Shape.Skewness M
#     Centrality.Closeness.Shape.Skewness YP
#     Centrality.ClusteringCoefficient.Dispersion.Coefficient Of Variation (Rank)
#     Centrality.ClusteringCoefficient.Dispersion.Uncorrected Coefficient Of Variation (Rank)
#     Centrality.Degree.Dispersion.Coefficient Of Variation (Rank)
#     Centrality.Degree.Dispersion.Uncorrected Coefficient Of Variation (Rank)
#     Centrality.Katz.Dispersion.Coefficient Of Variation (Rank)
#     Centrality.Katz.Dispersion.Uncorrected Coefficient Of Variation (Rank)
#     Centrality.PageRank.Dispersion.Coefficient Of Variation (Rank)
#     Centrality.PageRank.Dispersion.Uncorrected Coefficient Of Variation (Rank)
#     Connected Components
#     Directed
#     Partition.Communities.Dispersion.Coefficient Of Variation (Rank)
#     Partition.Communities.Dispersion.Uncorrected Coefficient Of Variation (Rank)
#     Partition.ConnectedComponents.Dispersion.Uncorrected Coefficient Of Variation
#     Partition.ConnectedComponents.Dispersion.Uncorrected Coefficient Of Variation (Rank)
#     Partition.ConnectedComponents.Dispersion.Uncorrected Standard Deviation
#     Partition.ConnectedComponents.Dispersion.Uncorrected Standard Deviation (Rank)
#     Partition.ConnectedComponents.Dispersion.Uncorrected Variance
#     Partition.ConnectedComponents.Dispersion.Uncorrected Variance (Rank)
#     Partition.ConnectedComponents.Location.Arithmetic Mean (Rank)
#     Partition.ConnectedComponents.Properties.Size
#     Self Loops
#     Weighted
# /Users/benjidayan/GDrive/eth_courses/GIRG/nemo-eva/src/feature_cleaner.py:47: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df_real = df_real.loc[complete_graphs]
# /Users/benjidayan/GDrive/eth_courses/GIRG/nemo-eva/src/feature_cleaner.py:48: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df_cleaned = df_features_cleaned.loc[complete_graphs]
# /Users/benjidayan/GDrive/eth_courses/GIRG/nemo-eva/src/feature_cleaner.py:99: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   variation = df_finite_filtered.std() / df_finite_filtered.mean() / (len(df_finite_filtered)-1)**0.5
# /Users/benjidayan/GDrive/eth_courses/GIRG/nemo-eva/src/feature_cleaner.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Graph"] = df_final.index

# %%
df_clean.loc[:, ['Graph', 'Model', 'Type', 'Nodes', 'Edges', 'alpha', 'Centrality.ClusteringCoefficient.Location.Arithmetic Mean', 'Centrality.Degree.Location.Arithmetic Mean']].sort_values(['Graph', 'Model'])
# Out:
#                  Graph         Model Type  Nodes  Edges               alpha  \
# 1164      bio-celegans  1d-cube-girg  bio    444   1649    2.33784616789571
# 1161      bio-celegans       1d-girg  bio    453   2096  2.4190309702109567
# 1165      bio-celegans  2d-cube-girg  bio    435   1637                 2.0
# 1162      bio-celegans       2d-girg  bio    450   2045   3.460511642053326
# 1163      bio-celegans       3d-girg  bio    453   2035               100.0
# ...                ...           ...  ...    ...    ...                 ...
# 1191  web-webbase-2001       BA full  web  16062  25593                None
# 1189  web-webbase-2001            ER  web  15340  25625                None
# 1192  web-webbase-2001      chung-lu  web  11704  25084                None
# 1193  web-webbase-2001    hyperbolic  web  14096  19802            1.795735
# 1188  web-webbase-2001    real-world  web  16062  25593                None
#
#       Centrality.ClusteringCoefficient.Location.Arithmetic Mean  \
# 1164                                           0.606983
# 1161                                           0.627487
# 1165                                           0.550821
# 1162                                           0.670343
# 1163                                           0.525261
# ...                                                 ...
# 1191                                           0.001381
# 1189                                           0.000194
# 1192                                           0.036669
# 1193                                           0.223127
# 1188                                           0.224316
#
#       Centrality.Degree.Location.Arithmetic Mean
# 1164                                    7.427928
# 1161                                    9.253863
# 1165                                    7.526437
# 1162                                    9.088889
# 1163                                    8.984547
# ...                                          ...
# 1191                                    3.186776
# 1189                                    3.340939
# 1192                                    4.286398
# 1193                                    2.809591
# 1188                                    3.186776
#
# [1881 rows x 8 columns]

# %%
df_real.shape
# Out:
# (200, 238)

# %%
DP = os.environ['DATA_PATH']
all_df = pd.read_csv(DP + '4-classification_results/accuracies/all.csv').T
small_deg_df = pd.read_csv(DP + '4-classification_results/accuracies/avg-degree-le-30.csv').T
large_deg_df = pd.read_csv(DP + '4-classification_results/accuracies/avg-degree-gt-30.csv').T
socfb_df = pd.read_csv(DP + '4-classification_results/accuracies/socfb.csv').T
not_socfb_df = pd.read_csv(DP + '4-classification_results/accuracies/not-socfb.csv').T
for df in [all_df, small_deg_df, large_deg_df, socfb_df, not_socfb_df]:
    df.columns = df.iloc[0]
    df.drop(df.index[0], inplace=True)

# %%
all_df.columns
# Out:
# Index(['1d-girg', '2d-girg', '3d-girg', 'BA circle', 'BA full', 'ER',
#        'chung-lu', 'hyperbolic'],
#       dtype='object', name='features')

# %%
all_df.loc[:, ['ER', 'hyperbolic', '1d-girg', '2d-girg', '1d-cube-girg', '2d-cube-girg']]
# Out:
# features                                                 ER hyperbolic  \
# Betweenness,Closeness,Diameter Max - mean          0.880117   0.894737
# Betweenness,Closeness,Diameter Max - median        0.938596   0.888889
# Betweenness,Closeness,Diameter Max - stats          0.97076   0.874269
# Betweenness,Closeness,Effective Diameter - mean    0.789474   0.605263
# Betweenness,Closeness,Effective Diameter - median  0.918129   0.654971
# ...                                                     ...        ...
# Nodes,Edges,Partition.Communities - stats          0.827485   0.888889
# Nodes,Edges,Partition.CoreDecomposition - mean     0.915205   0.871345
# Nodes,Edges,Partition.CoreDecomposition - median   0.842105   0.833333
# Nodes,Edges,Partition.CoreDecomposition - stats    0.964912   0.885965
# all (uncorrelated)                                 0.997076   0.938596
#
# features                                            1d-girg   2d-girg  \
# Betweenness,Closeness,Diameter Max - mean          0.847953  0.836257
# Betweenness,Closeness,Diameter Max - median        0.859649  0.856725
# Betweenness,Closeness,Diameter Max - stats         0.865497  0.877193
# Betweenness,Closeness,Effective Diameter - mean    0.616959  0.599415
# Betweenness,Closeness,Effective Diameter - median  0.859649  0.853801
# ...                                                     ...       ...
# Nodes,Edges,Partition.Communities - stats          0.856725  0.839181
# Nodes,Edges,Partition.CoreDecomposition - mean     0.862573  0.859649
# Nodes,Edges,Partition.CoreDecomposition - median   0.804094  0.807018
# Nodes,Edges,Partition.CoreDecomposition - stats    0.874269  0.871345
# all (uncorrelated)                                 0.944444  0.938596
#
# features                                          1d-cube-girg 2d-cube-girg
# Betweenness,Closeness,Diameter Max - mean             0.818713     0.812865
# Betweenness,Closeness,Diameter Max - median           0.850877     0.853801
# Betweenness,Closeness,Diameter Max - stats            0.874269     0.888889
# Betweenness,Closeness,Effective Diameter - mean       0.605263      0.55848
# Betweenness,Closeness,Effective Diameter - median     0.842105     0.845029
# ...                                                        ...          ...
# Nodes,Edges,Partition.Communities - stats             0.883041     0.850877
# Nodes,Edges,Partition.CoreDecomposition - mean        0.853801     0.842105
# Nodes,Edges,Partition.CoreDecomposition - median      0.812865     0.795322
# Nodes,Edges,Partition.CoreDecomposition - stats       0.874269     0.847953
# all (uncorrelated)                                    0.947368     0.961988
#
# [115 rows x 6 columns]

# %%
all_df.loc[:, ['ER', 'hyperbolic', '1d-girg', '1d-cube-girg']]
# Out:
# features                                                 ER hyperbolic  \
# Betweenness,Closeness,Diameter Max - mean          0.880117   0.894737
# Betweenness,Closeness,Diameter Max - median        0.938596   0.888889
# Betweenness,Closeness,Diameter Max - stats          0.97076   0.874269
# Betweenness,Closeness,Effective Diameter - mean    0.789474   0.605263
# Betweenness,Closeness,Effective Diameter - median  0.918129   0.654971
# ...                                                     ...        ...
# Nodes,Edges,Partition.Communities - stats          0.827485   0.888889
# Nodes,Edges,Partition.CoreDecomposition - mean     0.915205   0.871345
# Nodes,Edges,Partition.CoreDecomposition - median   0.842105   0.833333
# Nodes,Edges,Partition.CoreDecomposition - stats    0.964912   0.885965
# all (uncorrelated)                                 0.997076   0.938596
#
# features                                            1d-girg 1d-cube-girg
# Betweenness,Closeness,Diameter Max - mean          0.847953     0.818713
# Betweenness,Closeness,Diameter Max - median        0.859649     0.850877
# Betweenness,Closeness,Diameter Max - stats         0.865497     0.874269
# Betweenness,Closeness,Effective Diameter - mean    0.616959     0.605263
# Betweenness,Closeness,Effective Diameter - median  0.859649     0.842105
# ...                                                     ...          ...
# Nodes,Edges,Partition.Communities - stats          0.856725     0.883041
# Nodes,Edges,Partition.CoreDecomposition - mean     0.862573     0.853801
# Nodes,Edges,Partition.CoreDecomposition - median   0.804094     0.812865
# Nodes,Edges,Partition.CoreDecomposition - stats    0.874269     0.874269
# all (uncorrelated)                                 0.944444     0.947368
#
# [115 rows x 4 columns]

# %%
pre, post = all_df.loc[:, 'hyperbolic'].to_numpy(), all_df.loc[:, '1d-girg'].to_numpy()
scipy.stats.ttest_rel(pre, post, alternative="greater")
sns.swarmplot(post - pre)
# Out:
# TtestResult(statistic=-2.25027519232989, pvalue=0.9868249340710826, df=114)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
pre, post = all_df.loc[:, 'hyperbolic'].to_numpy(), all_df.loc[:, '1d-cube-girg'].to_numpy()
scipy.stats.ttest_rel(pre, post, alternative="greater")
sns.swarmplot(post - pre)
# Out:
# TtestResult(statistic=1.9472658341508526, pvalue=0.026981114855989263, df=114)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
pre, post = all_df.loc[:, '1d-girg'].to_numpy(), all_df.loc[:, '1d-cube-girg'].to_numpy()
scipy.stats.ttest_rel(pre, post, alternative="greater")
sns.swarmplot(post - pre)
# Out:
# TtestResult(statistic=3.1422371444396817, pvalue=0.0010684239495653614, df=114)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
pre, post = all_df.loc[:, '1d-girg'].to_numpy(), all_df.loc[:, '2d-girg'].to_numpy()
scipy.stats.ttest_rel(pre, post, alternative="greater")
sns.swarmplot(post - pre)
# Out:
# TtestResult(statistic=2.8606223785379057, pvalue=0.0025152896662757815, df=114)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
pre, post = all_df.loc[:, '2d-girg'].to_numpy(), all_df.loc[:, '2d-cube-girg'].to_numpy()
scipy.stats.ttest_rel(pre, post, alternative="greater")
sns.swarmplot(post - pre)
# Out:
# TtestResult(statistic=-1.8159677602875002, pvalue=0.9639982931603974, df=114)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
pre, post = all_df.loc[:, '1d-cube-girg'].to_numpy(), all_df.loc[:, '2d-cube-girg'].to_numpy()
scipy.stats.ttest_rel(pre, post, alternative="greater")
sns.swarmplot(post - pre)
# Out:
# TtestResult(statistic=-2.961915518981285, pvalue=0.9981393088533485, df=114)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
pre, post = all_df.loc[:, '1d-girg'].to_numpy(), all_df.loc[:, '2d-girg'].to_numpy()
scipy.stats.ttest_rel(pre, post, alternative="greater")
sns.swarmplot(post - pre)
# Out:
# TtestResult(statistic=1.1239673038967637, pvalue=0.13169405196590808, df=114)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
pre, post = all_df.loc[:, '2d-girg'].to_numpy(), all_df.loc[:, '2d-cube-girg'].to_numpy()
scipy.stats.ttest_rel(pre, post, alternative="greater")
sns.swarmplot(post - pre)
# Out:
# TtestResult(statistic=0.40228332380092463, pvalue=0.3441144065933724, df=114)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
socfb_df.loc[socfb_df.hyperbolic < 0.9, ['ER', 'hyperbolic', '1d-girg', '2d-girg', '3d-girg']]
# Out:
# features                                                  ER hyperbolic  \
# Betweenness,Closeness,Effective Diameter - mean     0.963636   0.863636
# ClusteringCoefficient,Degree Distribution.Power...       1.0   0.795455
# ClusteringCoefficient,Degree Distribution.Power...       1.0   0.859091
# Nodes,Edges - mean                                  0.495455       0.55
# Nodes,Edges,Betweenness - mean                      0.968182   0.581818
# Nodes,Edges,Betweenness - median                    0.927273   0.831818
# Nodes,Edges,Betweenness,Closeness,Effective Dia...  0.986364   0.836364
# Nodes,Edges,Betweenness,Closeness,Effective Dia...  0.977273   0.872727
# Nodes,Edges,Centrality.CoreDecomposition - median   0.986364   0.813636
# Nodes,Edges,Closeness - mean                        0.886364   0.709091
# Nodes,Edges,Closeness - median                      0.809091   0.736364
# Nodes,Edges,Closeness - stats                       0.990909   0.890909
# Nodes,Edges,Closeness,ClusteringCoefficient - mean  0.995455   0.640909
# Nodes,Edges,Closeness,ClusteringCoefficient - m...  0.995455   0.895455
# Nodes,Edges,Closeness,Degree - mean                 0.859091       0.65
# Nodes,Edges,ClusteringCoefficient - mean            0.995455       0.55
# Nodes,Edges,ClusteringCoefficient - median          0.995455   0.886364
# Nodes,Edges,ClusteringCoefficient,Betweenness -...  0.995455   0.581818
# Nodes,Edges,ClusteringCoefficient,Degree Distri...  0.995455       0.65
# Nodes,Edges,ClusteringCoefficient,Degree Distri...  0.995455   0.886364
# Nodes,Edges,ClusteringCoefficient,Degree Distri...       1.0   0.790909
# Nodes,Edges,ClusteringCoefficient,Effective Dia...       1.0   0.809091
# Nodes,Edges,Degree - mean                           0.504545   0.577273
# Nodes,Edges,Degree Distribution.Powerlaw.Alpha ...  0.995455   0.654545
# Nodes,Edges,Degree,Betweenness - mean               0.963636        0.6
# Nodes,Edges,Degree,ClusteringCoefficient - mean     0.995455   0.563636
# Nodes,Edges,Effective Diameter - mean               0.986364   0.836364
# Nodes,Edges,Katz - mean                             0.940909   0.863636
# Nodes,Edges,Katz - median                           0.977273   0.863636
# Nodes,Edges,Katz,ClusteringCoefficient - mean       0.995455   0.836364
# Nodes,Edges,Katz,Degree - mean                      0.936364   0.840909
# Nodes,Edges,PageRank - mean                         0.495455   0.540909
# Nodes,Edges,PageRank,ClusteringCoefficient - mean   0.995455   0.559091
# Nodes,Edges,PageRank,ClusteringCoefficient - me...  0.995455   0.890909
# Nodes,Edges,PageRank,Degree - mean                  0.504545   0.586364
#
# features                                             1d-girg   2d-girg  \
# Betweenness,Closeness,Effective Diameter - mean     0.813636  0.831818
# ClusteringCoefficient,Degree Distribution.Power...  0.786364  0.804545
# ClusteringCoefficient,Degree Distribution.Power...  0.872727  0.854545
# Nodes,Edges - mean                                  0.495455  0.495455
# Nodes,Edges,Betweenness - mean                      0.668182  0.618182
# Nodes,Edges,Betweenness - median                    0.986364  0.977273
# Nodes,Edges,Betweenness,Closeness,Effective Dia...  0.809091  0.809091
# Nodes,Edges,Betweenness,Closeness,Effective Dia...  0.981818  0.968182
# Nodes,Edges,Centrality.CoreDecomposition - median   0.790909  0.822727
# Nodes,Edges,Closeness - mean                        0.709091  0.695455
# Nodes,Edges,Closeness - median                      0.759091       0.8
# Nodes,Edges,Closeness - stats                       0.977273  0.972727
# Nodes,Edges,Closeness,ClusteringCoefficient - mean  0.709091  0.686364
# Nodes,Edges,Closeness,ClusteringCoefficient - m...  0.868182  0.845455
# Nodes,Edges,Closeness,Degree - mean                 0.640909  0.695455
# Nodes,Edges,ClusteringCoefficient - mean            0.568182  0.654545
# Nodes,Edges,ClusteringCoefficient - median          0.868182  0.859091
# Nodes,Edges,ClusteringCoefficient,Betweenness -...  0.645455  0.654545
# Nodes,Edges,ClusteringCoefficient,Degree Distri...  0.668182  0.654545
# Nodes,Edges,ClusteringCoefficient,Degree Distri...  0.854545  0.845455
# Nodes,Edges,ClusteringCoefficient,Degree Distri...  0.836364  0.809091
# Nodes,Edges,ClusteringCoefficient,Effective Dia...  0.827273  0.845455
# Nodes,Edges,Degree - mean                                0.5  0.504545
# Nodes,Edges,Degree Distribution.Powerlaw.Alpha ...  0.640909  0.613636
# Nodes,Edges,Degree,Betweenness - mean               0.590909  0.572727
# Nodes,Edges,Degree,ClusteringCoefficient - mean     0.559091  0.663636
# Nodes,Edges,Effective Diameter - mean               0.818182  0.836364
# Nodes,Edges,Katz - mean                             0.854545  0.854545
# Nodes,Edges,Katz - median                           0.863636  0.863636
# Nodes,Edges,Katz,ClusteringCoefficient - mean       0.836364  0.854545
# Nodes,Edges,Katz,Degree - mean                          0.85  0.854545
# Nodes,Edges,PageRank - mean                         0.495455  0.495455
# Nodes,Edges,PageRank,ClusteringCoefficient - mean   0.563636  0.663636
# Nodes,Edges,PageRank,ClusteringCoefficient - me...  0.963636  0.954545
# Nodes,Edges,PageRank,Degree - mean                       0.5       0.5
#
# features                                             3d-girg
# Betweenness,Closeness,Effective Diameter - mean     0.827273
# ClusteringCoefficient,Degree Distribution.Power...  0.813636
# ClusteringCoefficient,Degree Distribution.Power...  0.859091
# Nodes,Edges - mean                                  0.495455
# Nodes,Edges,Betweenness - mean                      0.559091
# Nodes,Edges,Betweenness - median                    0.972727
# Nodes,Edges,Betweenness,Closeness,Effective Dia...  0.827273
# Nodes,Edges,Betweenness,Closeness,Effective Dia...  0.963636
# Nodes,Edges,Centrality.CoreDecomposition - median   0.813636
# Nodes,Edges,Closeness - mean                        0.759091
# Nodes,Edges,Closeness - median                      0.804545
# Nodes,Edges,Closeness - stats                       0.977273
# Nodes,Edges,Closeness,ClusteringCoefficient - mean      0.75
# Nodes,Edges,Closeness,ClusteringCoefficient - m...  0.881818
# Nodes,Edges,Closeness,Degree - mean                 0.759091
# Nodes,Edges,ClusteringCoefficient - mean            0.609091
# Nodes,Edges,ClusteringCoefficient - median          0.868182
# Nodes,Edges,ClusteringCoefficient,Betweenness -...      0.65
# Nodes,Edges,ClusteringCoefficient,Degree Distri...  0.663636
# Nodes,Edges,ClusteringCoefficient,Degree Distri...  0.859091
# Nodes,Edges,ClusteringCoefficient,Degree Distri...  0.836364
# Nodes,Edges,ClusteringCoefficient,Effective Dia...      0.85
# Nodes,Edges,Degree - mean                                0.5
# Nodes,Edges,Degree Distribution.Powerlaw.Alpha ...  0.577273
# Nodes,Edges,Degree,Betweenness - mean               0.572727
# Nodes,Edges,Degree,ClusteringCoefficient - mean     0.586364
# Nodes,Edges,Effective Diameter - mean                    0.8
# Nodes,Edges,Katz - mean                             0.863636
# Nodes,Edges,Katz - median                           0.872727
# Nodes,Edges,Katz,ClusteringCoefficient - mean       0.877273
# Nodes,Edges,Katz,Degree - mean                      0.872727
# Nodes,Edges,PageRank - mean                              0.5
# Nodes,Edges,PageRank,ClusteringCoefficient - mean   0.609091
# Nodes,Edges,PageRank,ClusteringCoefficient - me...  0.931818
# Nodes,Edges,PageRank,Degree - mean                  0.495455

# %%
not_socfb_df.loc[not_socfb_df.hyperbolic < 0.8, ['ER', 'hyperbolic', '1d-girg', '2d-girg', '3d-girg']]
# Out:
# features                                                 ER hyperbolic  \
# Betweenness,Closeness,Diameter Max - mean          0.738889   0.566667
# Betweenness,Closeness,Diameter Max - median             0.9   0.594444
# Betweenness,Closeness,Diameter Max - stats         0.955556   0.661111
# Betweenness,Closeness,Effective Diameter - mean    0.544444        0.6
# Betweenness,Closeness,Effective Diameter - median  0.866667        0.6
# ...                                                     ...        ...
# Nodes,Edges,Partition.Communities - median         0.761111   0.688889
# Nodes,Edges,Partition.Communities - stats          0.855556   0.716667
# Nodes,Edges,Partition.CoreDecomposition - mean     0.833333   0.644444
# Nodes,Edges,Partition.CoreDecomposition - median   0.716667   0.616667
# Nodes,Edges,Partition.CoreDecomposition - stats    0.866667   0.661111
#
# features                                            1d-girg   2d-girg  \
# Betweenness,Closeness,Diameter Max - mean          0.505556       0.5
# Betweenness,Closeness,Diameter Max - median        0.633333  0.622222
# Betweenness,Closeness,Diameter Max - stats         0.661111  0.666667
# Betweenness,Closeness,Effective Diameter - mean    0.516667  0.511111
# Betweenness,Closeness,Effective Diameter - median  0.638889  0.661111
# ...                                                     ...       ...
# Nodes,Edges,Partition.Communities - median         0.722222  0.705556
# Nodes,Edges,Partition.Communities - stats          0.744444  0.727778
# Nodes,Edges,Partition.CoreDecomposition - mean     0.666667  0.666667
# Nodes,Edges,Partition.CoreDecomposition - median       0.65      0.65
# Nodes,Edges,Partition.CoreDecomposition - stats    0.694444  0.688889
#
# features                                            3d-girg
# Betweenness,Closeness,Diameter Max - mean          0.527778
# Betweenness,Closeness,Diameter Max - median        0.672222
# Betweenness,Closeness,Diameter Max - stats         0.655556
# Betweenness,Closeness,Effective Diameter - mean    0.522222
# Betweenness,Closeness,Effective Diameter - median  0.666667
# ...                                                     ...
# Nodes,Edges,Partition.Communities - median         0.755556
# Nodes,Edges,Partition.Communities - stats          0.727778
# Nodes,Edges,Partition.CoreDecomposition - mean     0.694444
# Nodes,Edges,Partition.CoreDecomposition - median       0.65
# Nodes,Edges,Partition.CoreDecomposition - stats    0.683333
#
# [107 rows x 5 columns]
